# %% [markdown]
# Insights Summary
#
# By: Josh Navarro
#
# Goal: Learn how to create insights summaries in Jupyter Notebook, using python pandas.
#
# Data: Created by ChatGPT

# %%
# Imports that we will use
import pandas as pd
import numpy as np

# %%
# Create the data
data = {
    "member_id": [
        201, 202, 203, 204, 205,
        206, 207, 208, 209, 210,
        211, 212, 213, 214, 215,
        216, 217, 218, 219, 220
    ],
    "join_date": [
        "2026-01-05", "2026-01-12", "2026-01-20", "2026-02-03", "2026-02-14",
        "2026-02-25", "2026-03-04", "2026-03-12", "2026-03-22", "2026-04-01",
        "2026-04-10", "2026-04-19", "2026-05-02", "2026-05-09", "2026-05-21",
        "2026-06-03", "2026-06-11", "2026-06-18", "2026-06-25", "2026-06-30"
    ],
    "membership_type": [
        "Basic", "Premium", "Basic", "Premium", "VIP",
        "Basic", "Premium", "VIP", "Basic", "Premium",
        "VIP", "Basic", "Premium", "VIP", "Basic",
        "Premium", "Basic", "VIP", "Premium", "Basic"
    ],
    "age_group": [
        "18-24", "25-34", "35-44", "25-34", "45-54",
        "18-24", "35-44", "25-34", "55+", "35-44",
        "45-54", "18-24", "25-34", "35-44", "55+",
        "45-54", "25-34", "35-44", "18-24", "55+"
    ],
    "signup_channel": [
        "Website", "Referral", "Walk-In", "Website", "Referral",
        "Social Media", "Website", "Referral", "Walk-In", "Website",
        "Referral", "Social Media", "Website", "Referral", "Walk-In",
        "Website", "Social Media", "Referral", "Website", "Walk-In"
    ],
    "monthly_fee": [
        29.99, 59.99, 29.99, 59.99, 99.99,
        29.99, 59.99, 99.99, 29.99, 59.99,
        99.99, 29.99, 59.99, 99.99, 29.99,
        59.99, 29.99, 99.99, 59.99, 29.99
    ],
    "visits_per_month": [
        4, 10, 3, 8, 15,
        5, 9, 14, 2, 7,
        16, 6, 11, 13, 3,
        8, 4, 12, 9, 2
    ],
    "classes_attended": [
        0, 4, 1, 3, 8,
        1, 5, 7, 0, 2,
        9, 1, 6, 7, 0,
        3, 1, 6, 4, 0
    ],
    "personal_training_sessions": [
        0, 1, 0, 2, 5,
        0, 1, 4, 0, 1,
        6, 0, 2, 4, 0,
        1, 0, 3, 2, 0
    ],
    "satisfaction_score": [
        6, 8, 5, 7, 9,
        6, 8, 9, 4, 7,
        10, 6, 8, 9, 5,
        7, 6, 8, 7, 4
    ],
    "cancelled": [
        "No", "No", "Yes", "No", "No",
        "No", "No", "No", "Yes", "No",
        "No", "No", "No", "No", "Yes",
        "No", "No", "No", "No", "Yes"
    ]
}

df = pd.DataFrame(data)

df["join_date"] = pd.to_datetime(df["join_date"])

df
# Out:
#     member_id  join_date membership_type age_group signup_channel  \
# 0         201 2026-01-05           Basic     18-24        Website
# 1         202 2026-01-12         Premium     25-34       Referral
# 2         203 2026-01-20           Basic     35-44        Walk-In
# 3         204 2026-02-03         Premium     25-34        Website
# 4         205 2026-02-14             VIP     45-54       Referral
# 5         206 2026-02-25           Basic     18-24   Social Media
# 6         207 2026-03-04         Premium     35-44        Website
# 7         208 2026-03-12             VIP     25-34       Referral
# 8         209 2026-03-22           Basic       55+        Walk-In
# 9         210 2026-04-01         Premium     35-44        Website
# 10        211 2026-04-10             VIP     45-54       Referral
# 11        212 2026-04-19           Basic     18-24   Social Media
# 12        213 2026-05-02         Premium     25-34        Website
# 13        214 2026-05-09             VIP     35-44       Referral
# 14        215 2026-05-21           Basic       55+        Walk-In
# 15        216 2026-06-03         Premium     45-54        Website
# 16        217 2026-06-11           Basic     25-34   Social Media
# 17        218 2026-06-18             VIP     35-44       Referral
# 18        219 2026-06-25         Premium     18-24        Website
# 19        220 2026-06-30           Basic       55+        Walk-In
#
#     monthly_fee  visits_per_month  classes_attended  \
# 0         29.99                 4                 0
# 1         59.99                10                 4
# 2         29.99                 3                 1
# 3         59.99                 8                 3
# 4         99.99                15                 8
# 5         29.99                 5                 1
# 6         59.99                 9                 5
# 7         99.99                14                 7
# 8         29.99                 2                 0
# 9         59.99                 7                 2
# 10        99.99                16                 9
# 11        29.99                 6                 1
# 12        59.99                11                 6
# 13        99.99                13                 7
# 14        29.99                 3                 0
# 15        59.99                 8                 3
# 16        29.99                 4                 1
# 17        99.99                12                 6
# 18        59.99                 9                 4
# 19        29.99                 2                 0
#
#     personal_training_sessions  satisfaction_score cancelled
# 0                            0                   6        No
# 1                            1                   8        No
# 2                            0                   5       Yes
# 3                            2                   7        No
# 4                            5                   9        No
# 5                            0                   6        No
# 6                            1                   8        No
# 7                            4                   9        No
# 8                            0                   4       Yes
# 9                            1                   7        No
# 10                           6                  10        No
# 11                           0                   6        No
# 12                           2                   8        No
# 13                           4                   9        No
# 14                           0                   5       Yes
# 15                           1                   7        No
# 16                           0                   6        No
# 17                           3                   8        No
# 18                           2                   7        No
# 19                           0                   4       Yes

# %% [markdown]
# Insights Summary
#
# Insights Summaries refer to using the the raw data to create a summary that will answer a question.

# %% [markdown]
# 1 Overall KPI Summary
#
# The overall KPI summary or Key Performance Indicators refer to basic indicators that indicate how the buiness is performing.

# %% [markdown]
# 2 Membership Type Summary

# %% [markdown]
# 3 Signup Channel Summary

# %% [markdown]
# 4 Age grooup Summary

# %% [markdown]
# 5 Cancellation Rate Summary

# %% [markdown]
# 6 Cacellation Rate by Membership Type

# %% [markdown]
# 7 Find Top Membership Type by Revenue

# %% [markdown]
# 8 Find Most Active Age Group

# %% [markdown]
# 9 Add percnet of Total Revenue

# %% [markdown]
# 10 Create a Final Insights Table

# %% [markdown]
# 11 Visualize Monthly Revenue by Membership Type

# %% [markdown]
# 12 visualize Average Visits by Age Group
