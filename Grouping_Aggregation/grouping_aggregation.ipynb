# %% [markdown]
# Grouping Aggregation
#
# By: Josh Navarro
#
# Goal: Learn grouping aggregation in jupyter notebook using python pandas
#
# Data: Create by ChatGPT

# %%
# Import that we are going to be using
import pandas as pd
import numpy as np

# %%
# Creating the dataframe

data = {
    "order_id": [
        1001, 1002, 1003, 1004, 1005,
        1006, 1007, 1008, 1009, 1010,
        1011, 1012, 1013, 1014, 1015,
        1016, 1017, 1018, 1019, 1020
    ],
    "customer_id": [
        "C001", "C002", "C003", "C001", "C004",
        "C002", "C005", "C003", "C006", "C004",
        "C001", "C007", "C005", "C006", "C002",
        "C008", "C003", "C007", "C004", "C005"
    ],
    "region": [
        "West", "South", "East", "West", "North",
        "South", "West", "East", "North", "North",
        "West", "South", "West", "North", "South",
        "East", "East", "South", "North", "West"
    ],
    "product_category": [
        "Electronics", "Clothing", "Home", "Electronics", "Clothing",
        "Home", "Electronics", "Clothing", "Home", "Electronics",
        "Home", "Clothing", "Clothing", "Electronics", "Electronics",
        "Home", "Electronics", "Home", "Clothing", "Electronics"
    ],
    "sales_channel": [
        "Online", "In-Store", "Online", "Mobile App", "Online",
        "In-Store", "Online", "Mobile App", "Online", "In-Store",
        "Mobile App", "Online", "In-Store", "Mobile App", "Online",
        "Online", "In-Store", "Mobile App", "Online", "In-Store"
    ],
    "units_sold": [
        2, 1, 4, 1, 3,
        2, 5, 2, 3, 1,
        4, 2, 1, 2, 3,
        5, 1, 2, 4, 2
    ],
    "unit_price": [
        699.99, 49.99, 89.99, 799.99, 39.99,
        129.99, 599.99, 59.99, 99.99, 899.99,
        79.99, 45.99, 55.99, 749.99, 649.99,
        119.99, 999.99, 139.99, 35.99, 549.99
    ],
    "discount_rate": [
        0.10, 0.05, 0.00, 0.15, 0.10,
        0.00, 0.20, 0.05, 0.10, 0.00,
        0.05, 0.10, 0.00, 0.15, 0.10,
        0.05, 0.20, 0.00, 0.10, 0.05
    ],
    "returned": [
        "No", "No", "Yes", "No", "No",
        "No", "No", "Yes", "No", "No",
        "No", "No", "No", "No", "Yes",
        "No", "No", "Yes", "No", "No"
    ]
}

df = pd.DataFrame(data)

df["revenue"] = df["units_sold"] * df["unit_price"] * (1 - df["discount_rate"])

df
# Out:
#     order_id customer_id region product_category sales_channel  units_sold  \
# 0       1001        C001   West      Electronics        Online           2
# 1       1002        C002  South         Clothing      In-Store           1
# 2       1003        C003   East             Home        Online           4
# 3       1004        C001   West      Electronics    Mobile App           1
# 4       1005        C004  North         Clothing        Online           3
# 5       1006        C002  South             Home      In-Store           2
# 6       1007        C005   West      Electronics        Online           5
# 7       1008        C003   East         Clothing    Mobile App           2
# 8       1009        C006  North             Home        Online           3
# 9       1010        C004  North      Electronics      In-Store           1
# 10      1011        C001   West             Home    Mobile App           4
# 11      1012        C007  South         Clothing        Online           2
# 12      1013        C005   West         Clothing      In-Store           1
# 13      1014        C006  North      Electronics    Mobile App           2
# 14      1015        C002  South      Electronics        Online           3
# 15      1016        C008   East             Home        Online           5
# 16      1017        C003   East      Electronics      In-Store           1
# 17      1018        C007  South             Home    Mobile App           2
# 18      1019        C004  North         Clothing        Online           4
# 19      1020        C005   West      Electronics      In-Store           2
#
#     unit_price  discount_rate returned    revenue
# 0       699.99           0.10       No  1259.9820
# 1        49.99           0.05       No    47.4905
# 2        89.99           0.00      Yes   359.9600
# 3       799.99           0.15       No   679.9915
# 4        39.99           0.10       No   107.9730
# 5       129.99           0.00       No   259.9800
# 6       599.99           0.20       No  2399.9600
# 7        59.99           0.05      Yes   113.9810
# 8        99.99           0.10       No   269.9730
# 9       899.99           0.00       No   899.9900
# 10       79.99           0.05       No   303.9620
# 11       45.99           0.10       No    82.7820
# 12       55.99           0.00       No    55.9900
# 13      749.99           0.15       No  1274.9830
# 14      649.99           0.10      Yes  1754.9730
# 15      119.99           0.05       No   569.9525
# 16      999.99           0.20       No   799.9920
# 17      139.99           0.00      Yes   279.9800
# 18       35.99           0.10       No   129.5640
# 19      549.99           0.05       No  1044.9810

# %% [markdown]
# Grouping Aggregation

# %% [markdown]
# 1 Group by One Column

# %% [markdown]
# 2 Group by One Column and Calculate Average

# %% [markdown]
# 3 Group by Mulitple Columns

# %% [markdown]
# 4 Count Rows in Each group

# %% [markdown]
# 5 Count Non-Missing Values

# %% [markdown]
# 6 Count Unique Values

# %% [markdown]
# 7 Use Multiple Aggregation on One column

# %% [markdown]
# 8 Use different aggregations for Different Columns

# %% [markdown]
# 9 Rename Aggregated Columns
