# %% [markdown]
# Visual Exploration
#
# By: Josh Navarro
#
# Goal: Learn to visually explore a dataframe in Jupyter Notebook using Python Pandas
#
# Data: ChatGPT

# %%
# Imports that I will be using

import pandas as pd

# %%
# Create the dataframe
df = pd.DataFrame({
    "product_id": [101, 102, 103, 104, 105, 106, 107, 108,
                   109, 110, 111, 112, 113, 114, 115],

    "product_category": ["Electronics", "Clothing", "Home", "Electronics", "Beauty",
                         "Clothing", "Home", "Electronics", "Beauty", "Clothing",
                         "Home", "Electronics", "Beauty", "Clothing", "Home"],

    "region": ["West", "East", "South", "North", "West",
               "South", "East", "West", "North", "East",
               "South", "North", "West", "South", "East"],

    "monthly_sales": [250, 180, 150, 300, 120,
                      210, 160, 330, 140, 220,
                      175, 310, 135, 205, 165],

    "revenue": [12500, 7200, 6000, 15000, 4800,
                8400, 6400, 16500, 5600, 8800,
                7000, 15500, 5400, 8200, 6600],

    "profit": [3200, 1800, 1500, 4100, 900,
               2100, 1600, 4500, 1100, 2300,
               1700, 4300, 1000, 2000, 1550],

    "customer_rating": [4.6, 4.1, 3.9, 4.8, 4.0,
                        4.2, 3.8, 4.9, 4.1, 4.3,
                        3.7, 4.7, 4.2, 4.0, 3.9],

    "returns": [8, 12, 10, 7, 15,
                11, 13, 6, 14, 10,
                12, 7, 16, 11, 13],

    "ad_spend": [2000, 1200, 900, 2500, 800,
                 1300, 950, 2700, 850, 1400,
                 1000, 2600, 900, 1250, 975]
})

df
# Out:
#     product_id product_category region  monthly_sales  revenue  profit  \
# 0          101      Electronics   West            250    12500    3200
# 1          102         Clothing   East            180     7200    1800
# 2          103             Home  South            150     6000    1500
# 3          104      Electronics  North            300    15000    4100
# 4          105           Beauty   West            120     4800     900
# 5          106         Clothing  South            210     8400    2100
# 6          107             Home   East            160     6400    1600
# 7          108      Electronics   West            330    16500    4500
# 8          109           Beauty  North            140     5600    1100
# 9          110         Clothing   East            220     8800    2300
# 10         111             Home  South            175     7000    1700
# 11         112      Electronics  North            310    15500    4300
# 12         113           Beauty   West            135     5400    1000
# 13         114         Clothing  South            205     8200    2000
# 14         115             Home   East            165     6600    1550
#
#     customer_rating  returns  ad_spend
# 0               4.6        8      2000
# 1               4.1       12      1200
# 2               3.9       10       900
# 3               4.8        7      2500
# 4               4.0       15       800
# 5               4.2       11      1300
# 6               3.8       13       950
# 7               4.9        6      2700
# 8               4.1       14       850
# 9               4.3       10      1400
# 10              3.7       12      1000
# 11              4.7        7      2600
# 12              4.2       16       900
# 13              4.0       11      1250
# 14              3.9       13       975

# %% [markdown]
# Visual Exploration
#
# Using graphs to quickly try to understand the patterns in your data.

# %% [markdown]
# 1 Bar Chart

# %% [markdown]
# 2 Horizontal Bar Chart

# %% [markdown]
# 3 Histogram

# %% [markdown]
# 4 Boxplot

# %% [markdown]
# 5 Scatter Plot

# %% [markdown]
# 6 Line Chart

# %% [markdown]
# 7 Pie Chart

# %% [markdown]
# 8 Grouped Bar Chart

# %% [markdown]
# 9 Correlation Heatmap

# %% [markdown]
# 10 Mulitple Histograms

# %% [markdown]
# 11 Multiple Boxplots

# %% [markdown]
# 12 Visual Exploration with Pandas Built-In Plots
